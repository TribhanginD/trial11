# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Tribhangin Dichpally**
# <br>Data scientist

# %% [markdown]
# *I am interested in data science because I believe it is the future.I am interested in new and upcoming technologies,and their applications on daily lives.*

# %% [markdown]
# ### The below code will multiply two numbers

# %%
a = 5
b = 6
print(a*b)
# Out:
# 30

# %% [markdown]
# ~~strikethrough exmaple~~
# This notebook was built on [IBM cloud](https://www.ibm.com/in-en/cloud).
#
# bulleted list
# * Item 1
# * Item 2
# * Item 3
#
#
# Numbered List
# 1. Item 1
# 2. Item 2
# 3. Item 3
#
#
# Blocked Quote:
# ```
# This is
# a blocked quote
# example.
# ```
